# %% [markdown]
# # Synthetic Data Generation — Week 5
#
# **Learning Objectives:**
# - Load a resume PDF as the source corpus for dataset generation
# - Use Claude to generate seed Q&A pairs grounded in the corpus
# - Expand seeds into a larger dataset and filter by quality score
# - Save the final dataset in ChatML format for fine-tuning
#
# **Estimated Time:** 30 minutes
#
# **Path Indicator:** Path-agnostic — the dataset produced here feeds into both Path A (MLX) and Path B (HF+TRL) in later notebooks.

# %%
import sys
import importlib
import json
import os
from pathlib import Path

sys.path.insert(0, "..")

import src
importlib.reload(src)

from dotenv import load_dotenv
load_dotenv(override=True)

# %matplotlib inline

from src.cost_tracker import CostTracker
from src.llm_client import LLMClient
from src.synthetic_data import SyntheticDatasetBuilder
from src.data_prep import (
    train_val_test_split,
    show_dataset_stats,
    save_jsonl,
)
from src.utils import append_to_reflection

tracker = CostTracker()
# SyntheticDatasetBuilder._call uses self._client.messages.create,
# so we pass the raw anthropic client (llm.claude_client).
llm = LLMClient(path="A")  # Path A initialises the Claude API client

print("Imports OK")
print(f"Claude client ready: {llm.claude_client is not None}")
# Out:
# ✓ Claude API client initialized
#   Default model: claude-sonnet-4-6
#   Available: claude-sonnet-4-6, claude-opus-4-6, claude-haiku-4-5-20251001
# Imports OK
# Claude client ready: True

# %% [markdown]
# ## Part 1: Loading the Source Corpus
#
# Our fine-tuning dataset will be generated **from** a resume. This is the core insight of synthetic data generation for SFT: you use a strong LLM (Claude) to distill knowledge from a raw document into structured (prompt, response) pairs that a smaller model can learn from.
#
# We try to load `../test_data/sample_resume.pdf` with `pypdf`. If pypdf is not installed or the file is not a valid PDF, we fall back to reading it as plain text.

# %%
RESUME_PATH = Path("..") / "test_data" / "sample_resume.pdf"

corpus_text = ""

# Try pypdf first
try:
    from pypdf import PdfReader
    reader = PdfReader(str(RESUME_PATH))
    pages_text = []
    for page in reader.pages:
        text = page.extract_text()
        if text:
            pages_text.append(text)
    corpus_text = "\n".join(pages_text)
    print(f"Loaded PDF via pypdf: {len(reader.pages)} page(s), {len(corpus_text)} chars")
except ImportError:
    print("pypdf not installed — trying plain-text fallback")
    print("Install with: pip install pypdf")
except Exception as e:
    print(f"pypdf failed ({e}) — trying plain-text fallback")

# Plain-text fallback
if not corpus_text:
    txt_path = RESUME_PATH.with_suffix(".txt")
    if txt_path.exists():
        corpus_text = txt_path.read_text(encoding="utf-8")
        print(f"Loaded plain text fallback: {len(corpus_text)} chars from {txt_path}")
    elif RESUME_PATH.with_suffix(".pdf").exists():
        # Read raw bytes and decode best-effort
        corpus_text = RESUME_PATH.read_bytes().decode("utf-8", errors="replace")
        print(f"Loaded raw bytes fallback: {len(corpus_text)} chars")
    else:
        corpus_text = (
            "Jane Doe — ML Engineer\n"
            "5 years experience in Python, PyTorch, and distributed training.\n"
            "Led a team of 4 engineers to build a real-time recommendation system serving 10M users.\n"
            "Education: B.S. Computer Science, Stanford University, 2019.\n"
            "Skills: Python, PyTorch, TensorFlow, AWS SageMaker, Kubernetes, Docker.\n"
            "Previous role: Data Scientist at DataCorp (2019-2022).\n"
            "Current role: Senior ML Engineer at TechStartup (2022-present).\n"
            "Published 2 papers at NeurIPS and ICML on efficient fine-tuning methods."
        )
        print(f"WARNING: No resume file found at {RESUME_PATH} — using placeholder text.")
        print(f"Place your resume PDF at: {RESUME_PATH.resolve()}")

print()
print("First 500 characters of corpus:")
print("-" * 40)
print(corpus_text[:500])
# Out:
# Loaded PDF via pypdf: 1 page(s), 2082 chars
#
# First 500 characters of corpus:
# ----------------------------------------
# GIULIA
# GONZALEZ
# Python Developer
# ggonzalez@email.com
# (123) 456-7890
# Detroit, MI
# LinkedIn
# Github
# EDUCATION
# M.S.
# Computer Science
# University of Chicago
# 2014 - 2016
# Chicago, IL
# B.S.
# Computer Science
# University of Pittsburgh
# 2010 - 2014
# Pittsburgh, PA
# SKILLS
# HTML/ CSS
# SQL (PostgreSQL, Oracle)
# JavaScript (Angular)
# Python (Django)
# REST APIs (GraphQL)
# AWS (Redshift, S3)
# Git
# WORK EXPERIENCE
# Python Developer
# DoorDash
# September 2017 - current Detroit, MI
# · Worked on building new Angular components for the

# %% [markdown]
# ## Part 2: Seed Generation
#
# We pass the corpus text to `SyntheticDatasetBuilder.seed_from_corpus()`. Claude reads the resume and generates diverse Q&A pairs covering the key facts: skills, roles, achievements, education, and projects.
#
# Budget cap is set to `$3.00` — seed generation for 10 examples typically costs `$0.02–0.05`.

# %%
# SyntheticDatasetBuilder._call calls self._client.messages.create(model=self._client.default_model).
# anthropic.Anthropic has .messages.create but no .default_model, so we build a thin shim.
class _ClaudeClientShim:
    """Wraps anthropic.Anthropic to add a .default_model attribute."""
    def __init__(self, anthropic_client, model: str):
        self.messages = anthropic_client.messages
        self.default_model = model

from src.config import CLAUDE_MODEL
claude_shim = _ClaudeClientShim(llm.claude_client, CLAUDE_MODEL)

builder = SyntheticDatasetBuilder(claude_shim, max_budget_usd=3.0)

print("Generating 10 seed Q&A pairs from resume corpus...")
print()

seeds = builder.seed_from_corpus(corpus_text, n_seeds=10)

print()
print("=" * 60)
print(f"Generated {len(seeds)} seeds:")
print("=" * 60)
for i, seed in enumerate(seeds):
    print(f"\n[{i+1}] Q: {seed['question']}")
    print(f"     A: {seed['answer'][:200]}{'...' if len(seed['answer']) > 200 else ''}")
# Out:
# [synthetic_data] SyntheticDatasetBuilder initialised (budget cap: $3.00)
# Generating 10 seed Q&A pairs from resume corpus...
#
# [synthetic_data] Generating 10 seed Q&A pairs from corpus (2082 chars)...
#   [1/10] Q: What is Giulia Gonzalez's educational background?
#   [2/10] Q: What technical skills does Giulia Gonzalez list on her resume?
#   [3/10] Q: What quantifiable impact did Giulia have on the customer-facing web app at DoorD
#   [4/10] Q: How did Giulia Gonzalez contribute to revenue growth at DoorDash?
#   [5/10] Q: What was the measurable outcome of Giulia's test coverage work at DoorDash?
#   [6/10] Q: What were Giulia Gonzalez's key responsibilities and achievements during her int
#   [7/10] Q: What tools and technologies did Giulia use in her Cryptocurrency Price Tracker p
#   [8/10] Q: How long has Giulia Gonzalez been working at DoorDash, and what is her role ther
#   [9/10] Q: What agile and collaborative experiences does Giulia Gonzalez highlight in her w
#   [10/10] Q: What testing frameworks or methodologies has Giulia Gonzalez used, and what resu
# [synthetic_data] seed_from_corpus done: 10 seeds (spent so far: $0.0170)
#
# ============================================================
# Generated 10 seeds:
# ============================================================
#
# [1] Q: What is Giulia Gonzalez's educational background?
#      A: Giulia Gonzalez holds two degrees in Computer Science. She earned her B.S. in Computer Science from the University of Pittsburgh (2010–2014) in Pittsburgh, PA, and her M.S. in Computer Science from th...
#
# [2] Q: What technical skills does Giulia Gonzalez list on her resume?
#      A: Giulia Gonzalez's listed skills include HTML/CSS, SQL (PostgreSQL and Oracle), JavaScript (Angular), Python (Django), REST APIs (GraphQL), AWS (Redshift and S3), and Git.
#
# [3] Q: What quantifiable impact did Giulia have on the customer-facing web app at DoorDash through her Angular component work?
#      A: By building new Angular components for the customer-facing web app at DoorDash, Giulia improved the time on page for the average user by 2 minutes.
#
# [4] Q: How did Giulia Gonzalez contribute to revenue growth at DoorDash?
#      A: At DoorDash, Giulia acquired and ingested data to build and maintain data pipelines, which led to discovering an opportunity for a new site feature. This ultimately boosted revenue by 6%.
#
# [5] Q: What was the measurable outcome of Giulia's test coverage work at DoorDash?
#      A: By building extensive test coverage for all new features at DoorDash, Giulia helped reduce the number of customer complaints by 23%.
#
# [6] Q: What were Giulia Gonzalez's key responsibilities and achievements during her internship at Knewton?
#      A: During her Python Developer Internship at Knewton (April 2016 – April 2017), Giulia implemented RESTful APIs in Django that increased the internal analytics team's reporting speed by 24%, built a unit...
#
# [7] Q: What tools and technologies did Giulia use in her Cryptocurrency Price Tracker project?
#      A: In her Cryptocurrency Price Tracker project, Giulia incorporated API calls to several applications, stored data efficiently in a PostgreSQL backend, and utilized D3.js to allow users to dynamically vi...
#
# [8] Q: How long has Giulia Gonzalez been working at DoorDash, and what is her role there?
#      A: Giulia Gonzalez has been working at DoorDash as a Python Developer since September 2017 and is currently still employed there, based in Detroit, MI. This means she has held the role for several years ...
#
# [9] Q: What agile and collaborative experiences does Giulia Gonzalez highlight in her work history?
#      A: At DoorDash, Giulia collaborated with an agile team of 6 and helped prioritize and scope feature requests to ensure the highest-impact features were addressed first. She also communicated with interna...
#
# [10] Q: What testing frameworks or methodologies has Giulia Gonzalez used, and what results did they produce?
#      A: Giulia has experience with two testing approaches. At Knewton, she used Selenium to build a unit testing infrastructure for a client web application, which reduced client-reported bugs by 11% month ov...

# %% [markdown]
# ## Part 3: Expansion and Filtering
#
# **Expansion:** We call `.expand(seeds, factor=2)` to generate 2 rephrased variations per seed, giving us `10 seeds + 20 variations = 30 total` records. This diversity is important — the model should learn to answer the same question phrased many different ways.
#
# **Filtering:** We call `.critique_and_filter(records, min_score=3.0)`. Claude scores each record on a 1–5 quality scale and we discard those below the threshold. This removes hallucinations and off-topic examples.

# %%
print("Expanding seeds (factor=2)...")
expanded = builder.expand(seeds, factor=2)
print(f"\nExpansion complete: {len(expanded)} total records")
# Out:
# Expanding seeds (factor=2)...
# [synthetic_data] Expanding 10 seeds by factor 2...
#   Seed 1/10: added 2 variations (spent: $0.0229)
#   Seed 2/10: added 2 variations (spent: $0.0293)
#   Seed 3/10: added 2 variations (spent: $0.0339)
#   Seed 4/10: added 2 variations (spent: $0.0395)
#   Seed 5/10: added 2 variations (spent: $0.0436)
#   Seed 6/10: added 2 variations (spent: $0.0544)
#   Seed 7/10: added 2 variations (spent: $0.0605)
#   Seed 8/10: added 2 variations (spent: $0.0643)
#   Seed 9/10: added 2 variations (spent: $0.0728)
#   Seed 10/10: added 2 variations (spent: $0.0805)
# [synthetic_data] expand done: 10 seeds + 20 variations = 30 total
#
# Expansion complete: 30 total records

# %%
print("Scoring and filtering records (min_score=3.0)...")
filtered = builder.critique_and_filter(expanded, min_score=3.0)

print()
print(f"Before filtering : {len(expanded)} records")
print(f"After filtering  : {len(filtered)} records")
removed = len(expanded) - len(filtered)
print(f"Removed          : {removed} low-quality records")

if filtered:
    scores = [r['score'] for r in filtered]
    print(f"Score range      : {min(scores):.1f} – {max(scores):.1f}")
    print(f"Mean score       : {sum(scores)/len(scores):.2f}")
# Out:
# Scoring and filtering records (min_score=3.0)...
# [synthetic_data] Scoring 30 records (min_score=3.0)...
#   Scored 10/30 (spent: $0.0947)
#   Scored 20/30 (spent: $0.1115)
#   Scored 30/30 (spent: $0.1304)
# [synthetic_data] Score distribution: {1: 11, 2: 16, 3: 1, 4: 2, 5: 0}
# [synthetic_data] critique_and_filter: kept 3/30 records (score >= 3.0)
#
# Before filtering : 30 records
# After filtering  : 3 records
# Removed          : 27 low-quality records
# Score range      : 3.0 – 4.0
# Mean score       : 3.67

# %% [markdown]
# ## Part 4: Save Dataset
#
# We convert to ChatML format, split 80/10/10, and save the splits.

# %%
# Convert to ChatML messages format
system_prompt = (
    "You are a professional assistant answering questions about a candidate's resume. "
    "Be concise, accurate, and professional."
)
chatml_records = builder.to_chatml(filtered, system_prompt=system_prompt)

print(f"Converted {len(chatml_records)} records to ChatML format")
print()
print("Sample record:")
print(json.dumps(chatml_records[0], indent=2)[:600])
# Out:
# [synthetic_data] to_chatml: converted 3 records to ChatML message format
# Converted 3 records to ChatML format
#
# Sample record:
# {
#   "messages": [
#     {
#       "role": "system",
#       "content": "You are a professional assistant answering questions about a candidate's resume. Be concise, accurate, and professional."
#     },
#     {
#       "role": "user",
#       "content": "What is Giulia Gonzalez's educational background?"
#     },
#     {
#       "role": "assistant",
#       "content": "Giulia Gonzalez holds two degrees in Computer Science. She earned her B.S. in Computer Science from the University of Pittsburgh (2010\u20132014) in Pittsburgh, PA, and her M.S. in Computer Science from the University of Chicago (2014\u20132016) in C

# %%
# Train / val / test split (80 / 10 / 10)
train_records, val_records, test_records = train_val_test_split(
    chatml_records,
    ratios=(0.8, 0.1, 0.1),
    seed=42
)

# Save splits
OUTPUT_DIR = Path("..") / "outputs"
OUTPUT_DIR.mkdir(exist_ok=True)

# We need flat text for show_dataset_stats — format each record as a text string
from src.data_prep import format_chatml

def to_text_records(records):
    return [{"text": format_chatml(r["messages"])} for r in records]

train_text = to_text_records(train_records)
val_text   = to_text_records(val_records)
test_text  = to_text_records(test_records)

print("Train split:")
show_dataset_stats(train_text)
print()
print("Val split:")
show_dataset_stats(val_text)
print()
print("Test split:")
show_dataset_stats(test_text)
# Out:
# [data_prep] Split 3 records -> train=2, val=0, test=1 (ratios=(0.8, 0.1, 0.1), seed=42)
# Train split:
# [data_prep] Dataset stats:
#   count       : 2
#   avg chars   : 629.0
#   min chars   : 511
#   max chars   : 747
#   sample entry: {"text": "<|im_start|>system\nYou are a professional assistant answering questions about a candidate's resume. Be concise, accurate, and professional.<|im_end|>\n<|im_start|>user\nWhat agile and colla
#
# Val split:
# [data_prep] Dataset stats:
#   count       : 0
#   avg chars   : 0
#   min chars   : 0
#   max chars   : 0
#   sample entry: {}
#
# Test split:
# [data_prep] Dataset stats:
#   count       : 1
#   avg chars   : 1162.0
#   min chars   : 1162
#   max chars   : 1162
#   sample entry: {"text": "<|im_start|>system\nYou are a professional assistant answering questions about a candidate's resume. Be concise, accurate, and professional.<|im_end|>\n<|im_start|>user\nHow does Giulia Gonz
# {'count': 1,
#  'avg_chars': 1162.0,
#  'min_chars': 1162,
#  'max_chars': 1162,
#  'sample': {'text': "<|im_start|>system\nYou are a professional assistant answering questions about a candidate's resume. Be concise, accurate, and professional.<|im_end|>\n<|im_start|>user\nHow does Giulia Gonzalez's work history demonstrate her ability to function within agile and team-oriented environments?<|im_end|>\n<|im_start|>assistant\nGiulia Gonzalez's work history showcases strong agile and collaborative capabilities across multiple roles. At DoorDash, she was an active member of an agile team of 6, where she contributed to prioritizing and scoping feature requests to ensure the most impactful work was tackled first. She also served as a communication bridge between internal teams and stakeholders to align on effective user experience solutions. At Knewton, she demonstrated her ability to work in smaller, focused team settings by collaborating closely with another developer, delivering regular updates to a leadership team of 3, and contributing to writing scalable code alongside a team of 4 interns and 1 developer. Together, these experiences reflect her comfort with iterative workflows, cross-functional communication, and collaborative development.<|im_end|>\n"}}

# %%
# Save all splits
dataset_path = str(OUTPUT_DIR / "synthetic_dataset.jsonl")
train_path   = str(OUTPUT_DIR / "synthetic_train.jsonl")
val_path     = str(OUTPUT_DIR / "synthetic_val.jsonl")
test_path    = str(OUTPUT_DIR / "synthetic_test.jsonl")

# Full dataset (all records)
save_jsonl(chatml_records, dataset_path)
# Splits
save_jsonl(train_records, train_path)
save_jsonl(val_records,   val_path)
save_jsonl(test_records,  test_path)

print()
print("Files saved:")
for p in [dataset_path, train_path, val_path, test_path]:
    size_kb = Path(p).stat().st_size / 1024 if Path(p).exists() else 0
    print(f"  {p}  ({size_kb:.1f} KB)")
# Out:
# [data_prep] Saved 3 records to ../outputs/synthetic_dataset.jsonl
# [data_prep] Saved 2 records to ../outputs/synthetic_train.jsonl
# [data_prep] Saved 0 records to ../outputs/synthetic_val.jsonl
# [data_prep] Saved 1 records to ../outputs/synthetic_test.jsonl
#
# Files saved:
#   ../outputs/synthetic_dataset.jsonl  (2.5 KB)
#   ../outputs/synthetic_train.jsonl  (1.3 KB)
#   ../outputs/synthetic_val.jsonl  (0.0 KB)
#   ../outputs/synthetic_test.jsonl  (1.2 KB)

# %% [markdown]
# ### TODO 1
#
# Add 3 more seed questions manually. Think about what topics the auto-generated seeds may have missed (edge cases, soft skills, specific projects, compensation, timeline, etc.).
#
# In the markdown cell below, answer: **What topics does the current dataset miss?**

# %%
# TODO 1: Add 3 manual seeds and merge into the dataset
# Hardcode as {"question": ..., "answer": ...} dicts

manual_seeds = [
    {
        "question": "What is your preferred work environment — remote, hybrid, or in-office?",
        "answer": "I prefer a hybrid setup with 2-3 days in office for collaborative sessions and the rest remote for deep work.",
    },
    {
        "question": "Can you describe a time when you had to learn a new technology quickly?",
        "answer": "When our team adopted Kubernetes, I built a proof-of-concept deployment in one week by combining documentation, tutorials, and pair programming with an SRE.",
    },
    {
        "question": "What salary range are you targeting?",
        "answer": "I am targeting $180k–$220k base depending on the total compensation package, including equity and benefits.",
    },
]

# Convert to ChatML and merge
manual_chatml = builder.to_chatml(manual_seeds, system_prompt=system_prompt)
augmented_records = chatml_records + manual_chatml

print(f"Original records : {len(chatml_records)}")
print(f"Manual seeds     : {len(manual_seeds)}")
print(f"Augmented total  : {len(augmented_records)}")

# Save augmented dataset
augmented_path = str(OUTPUT_DIR / "synthetic_dataset_augmented.jsonl")
save_jsonl(augmented_records, augmented_path)
print(f"Saved augmented dataset to: {augmented_path}")
# Out:
# [synthetic_data] to_chatml: converted 3 records to ChatML message format
# Original records : 3
# Manual seeds     : 3
# Augmented total  : 6
# [data_prep] Saved 6 records to ../outputs/synthetic_dataset_augmented.jsonl
# Saved augmented dataset to: ../outputs/synthetic_dataset_augmented.jsonl

# %%
# TODO 1 reflection -- edit your answer below, then run this cell.
todo1_reflection = """[Replace with your answer]

Hint: List your 3 manual seed questions and explain in 2-3 sentences what topics the auto-generated seeds missed (e.g. soft skills, compensation, work environment, timeline, edge-case projects). Why did the auto seeds miss these -- is it a property of the corpus, the prompt template, or the LLM's defaults?
"""
print(todo1_reflection)

# %% [markdown]
# ### TODO 2
#
# What is **EvolInstruct** and how does it differ from what we did? Answer in 2–3 sentences.
#
# Hint: EvolInstruct is the core technique behind WizardLM. What makes it "evolvable"?

# %%
# TODO 2 reflection -- edit your answer below, then run this cell.
todo2_reflection = """[Replace with your answer]

Hint: In 2-3 sentences, define EvolInstruct (the WizardLM technique) and contrast it with what we did in this notebook. Mention (a) that EvolInstruct iteratively rewrites prompts to be harder/more complex via operations like 'add constraints' or 'deepen reasoning', and (b) that our pipeline is corpus-grounded (seed -> expand -> filter against a resume) rather than open-ended difficulty evolution.
"""
print(todo2_reflection)

# %% [markdown]
# ## Summary

# %%
tracker.report()

# Build reflection from student TODO answers (auto-captured)
section_text = (
    "### TODO 1\n" + (todo1_reflection if 'todo1_reflection' in dir() else "[not completed]") + "\n\n" +
    "### TODO 2\n" + (todo2_reflection if 'todo2_reflection' in dir() else "[not completed]")
)
append_to_reflection(
    notebook="03",
    section_title="Synthetic Data Generation",
    reflection_content=section_text,
)
print("Reflection auto-saved to outputs/homework_reflection.md")
